# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

#Dash
import dash
import dash_core_components as dcc
from dash import html
from dash.dependencies import Input, Output
import re
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /tmp/ipykernel_26620/1269461808.py:17: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`

# %%
file_path = "/Users/jeremyrodriguez/Desktop/PMC Data/PMC Project/TrackingMain.csv"

df= pd.read_csv(file_path)


#Pull Location and Direction. Will be useful for having the total volume over time
df['Location'] = df['Location In'].str.replace(r' in| out', '', case=False, regex=True)
df['Date_Time'] = pd.to_datetime(df['Date'] + ' ' + df['Hour'].astype(str) + ':00:00')
df=df.drop('Unnamed: 0',axis = 1)

# %%
df
# Out:
#        PassingID eGIFTID  Bib (Tag)           Location In      time  \
# 0          404.0  KM0096       5429  Wrentham in Saturday  05:27:12
# 1         3708.0  MS0307       1940       Whitinsville In  05:56:43
# 2         3709.0  TP0251       1697      Whitinsville Out  06:00:07
# 3         3710.0  JH0588        885       Whitinsville In  06:00:52
# 4         3711.0  MS0307       1940      Whitinsville Out  06:04:02
# ...          ...     ...        ...                   ...       ...
# 73897    12773.0  EN0041       5479      Wellesley Finish  14:55:01
# 73898    16060.0  CH0352       5306      Wellesley Finish  15:18:30
# 73899    16426.0  EH0210       5307      Wellesley Finish  15:18:30
# 73900    22635.0  RV0056       5692      Wellesley Finish  15:38:35
# 73901    23000.0  NB0156       5062      Wellesley Finish  15:52:42
#
#              Date  Hour           Location           Date_Time
# 0      2023-08-05     5  Wrentham Saturday 2023-08-05 05:00:00
# 1      2023-08-05     5       Whitinsville 2023-08-05 05:00:00
# 2      2023-08-05     6       Whitinsville 2023-08-05 06:00:00
# 3      2023-08-05     6       Whitinsville 2023-08-05 06:00:00
# 4      2023-08-05     6       Whitinsville 2023-08-05 06:00:00
# ...           ...   ...                ...                 ...
# 73897  2023-08-06    14   Wellesley Finish 2023-08-06 14:00:00
# 73898  2023-08-06    15   Wellesley Finish 2023-08-06 15:00:00
# 73899  2023-08-06    15   Wellesley Finish 2023-08-06 15:00:00
# 73900  2023-08-06    15   Wellesley Finish 2023-08-06 15:00:00
# 73901  2023-08-06    15   Wellesley Finish 2023-08-06 15:00:00
#
# [73902 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

in_entries = df[df['Location In'].str.contains('In', case = False)]
out_entries = df[df['Location In'].str.contains('Out', case = False)]

unique_locations = df['Location In'].str.extract(r'(.*?)( In| Out|$)')[0].unique()
water_stop_data = df[df['Location'].str.contains('Whitinsville')]

# Calculate rider volume over time
time_intervals = water_stop_data['Date_Time']
rider_volume = []
volume = 0
for time in time_intervals:
    in_count = len(in_entries[in_entries['Date_Time'] == time])
    out_count = len(out_entries[out_entries['Date_Time'] == time])
    volume += in_count - out_count
    rider_volume.append(volume)

# Create a line graph
plt.figure(figsize=(10, 6))
plt.plot(time_intervals, rider_volume)
plt.xlabel('Time')
plt.ylabel('Rider Volume')
plt.title('Rider Volume Over Time at Whitinsville Water Stop')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Dropdown(
        id='location-dropdown',
        options=[{'label': i, 'value': i} for i in df['Location In'].unique()],
        value='Location1'  # Default value
    ),
    dcc.Graph(id='riders-plot')
])

# Define callback to update graph
@app.callback(
    Output('riders-plot', 'figure'),
    [Input('location-dropdown', 'value')]
)
def update_graph(selected_location):
    filtered_df = df[df['Location In'] == selected_location]
    fig = px.line(filtered_df, x='time', y='riders',labels={'riders': 'Number of Riders', 'Hour': 'Hour'},
                 title=f'Riders per Hour at {selected_location}')
    return fig


# Run the app
if __name__ == '__main__':
    app.run_server(mode='external')  # Use 'external' if you want to open the app in a new browser tab
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2023-09-27 16:36:39,751] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/dash/dash.py", line 1297, in dispatch
#     ctx.run(
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/dash/_callback.py", line 437, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_26620/883806651.py", line 19, in update_graph
#     fig = px.line(filtered_df, x='time', y='riders',labels={'riders': 'Number of Riders', 'Hour': 'Hour'},
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/plotly/express/_chart_types.py", line 264, in line
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py", line 1990, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py", line 1405, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/jeremyrodriguez/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py", line 1207, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['PassingID', 'eGIFTID', 'Bib (Tag)', 'Location In', 'time', 'Date', 'Hour', 'Location', 'Date_Time'] but received: riders
